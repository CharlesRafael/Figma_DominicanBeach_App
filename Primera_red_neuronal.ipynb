# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesRafael/Figma_DominicanBeach_App/blob/main/Primera_red_neuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
celcius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("Comienza entrenamiento...")
historial = modelo.fit(celcius, fahrenheit, epochs=1000, verbose=False)
print("Modelo entrenado!")
# Out:
# Comienza entrenamiento...
# Modelo entrenado!

# %%
#Esto hace una grafica
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
#Esto corre un ejemplo con datos que le insertes
print("Hagamos una prediccion!")
resultado = modelo.predict([53.0])
print("El resultado es " + str(resultado) + " fahrenheit!")
# Out:
# Hagamos una prediccion!
# 1/1 [==============================] - 0s 40ms/step
# El resultado es [[127.23114]] fahrenheit!

# %%
print("Variables internas del modelo")
print(capa.get_weights())
# Out:
# Variables internas del modelo
# [array([[1.7981445]], dtype=float32), array([31.929478], dtype=float32)]
